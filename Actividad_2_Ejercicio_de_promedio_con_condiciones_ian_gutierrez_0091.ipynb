# %% [markdown]
# <a href="https://colab.research.google.com/github/josafatian771-max/-Actividad-2.-Ejercicio-de-promedio-con-condiciones./blob/main/Actividad_2_Ejercicio_de_promedio_con_condiciones_ian_gutierrez_0091.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre = input("Escribe tu nombre: ")
edad = int(input("Escribe tu edad: "))

print(f"Hola {nombre}, tienes {edad}")


calificacion1 = float(input("Calificacion 1: "))
calificacion2 = float(input("Calificacion 2: "))
calificacion3 = float(input("Calificacion 3: "))

promedio = (calificacion1 + calificacion2 + calificacion3) / 3

if promedio == 10:
    print("Gran trabajo")
elif promedio >= 6 and promedio < 10:
    print("Aprobado")
elif promedio < 6:
    print("Reprobado")
# Out:
# Escribe tu nombre: ian
# Escribe tu edad: 15
# Hola ian, tienes 15
# Calificacion 1: 10
# Calificacion 2: 8
# Calificacion 3: 9
# Aprobado
